# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as py
# Out:
# Mounted at /content/drive

# %%
#불법주정차데이터1에서 했던 CSV파일을 가져온다.
file_path = '/content/drive/MyDrive/불법주차장데이터.csv'

data1 = pd.read_csv(file_path, encoding='cp949')

# %%
data1
df2 = data1.copy()

# %%
df2 = data1.dropna(axis=0, how='any', subset='구별구분') # 동과 구 모두 NULL값을 가진 Row 삭제

# %%
df2 = df2.drop('동별구분', axis=1) #동별구분 값이 더 이상 필요하지 않음으로 삭제

# %%
df2 # 확인결과 3,070,526의 row 중, 2,14,010의 값들만 남음
# Out:
#          Unnamed: 0  구별구분     민원접수일    민원접수시간                     주소  \
# 0                 0   강서구  20210929  00:05:00      서울 강서구 화곡로66길 130
# 1                 1    중구  20210929  00:38:00  중구 다산로48길 33 단우물어린이집앞
# 2                 2    중구  20210929  00:38:00        서울특별시 중구 마장로 19
# 3                 3   강서구  20210929  00:50:00   서울특별시 강서구 까치산로15길 21
# 4                 4    중구  20210929  01:15:00       서울특별시 중구 다산로 293
# ...             ...   ...       ...       ...                    ...
# 3070517     3070517   서초구  20240313  23:49:00    서울특별시 서초구 잠원로 213-3
# 3070520     3070520   광진구  20240313  23:54:00    광진구 자양로32길74 교차로모퉁이
# 3070524     3070524   관악구  20240313  23:55:00  신사동 554-23/ 앞 이면도로 주변
# 3070525     3070525  동대문구  20240313  23:56:00    서울 동대문구 휘경동 183-127
# 3070526     3070526   마포구  20240313  23:56:00   서울특별시 마포구 희우정로20길 71
#
#                  경도         위도
# 0        126.859911  37.555537
# 1        127.018013  37.567483
# 2        127.012793  37.569183
# ...

# %%
df2 = df2.drop(columns=['Unnamed: 0'])

# %%
df2
# Out:
#          구별구분     민원접수일    민원접수시간                     주소          경도  \
# 0         강서구  20210929  00:05:00      서울 강서구 화곡로66길 130  126.859911
# 1          중구  20210929  00:38:00  중구 다산로48길 33 단우물어린이집앞  127.018013
# 2          중구  20210929  00:38:00        서울특별시 중구 마장로 19  127.012793
# 3         강서구  20210929  00:50:00   서울특별시 강서구 까치산로15길 21  126.847125
# 4          중구  20210929  01:15:00       서울특별시 중구 다산로 293  127.015703
# ...       ...       ...       ...                    ...         ...
# 3070517   서초구  20240313  23:49:00    서울특별시 서초구 잠원로 213-3  127.014999
# 3070520   광진구  20240313  23:54:00    광진구 자양로32길74 교차로모퉁이  127.089311
# 3070524   관악구  20240313  23:55:00  신사동 554-23/ 앞 이면도로 주변  127.024768
# 3070525  동대문구  20240313  23:56:00    서울 동대문구 휘경동 183-127  127.056992
# 3070526   마포구  20240313  23:56:00   서울특별시 마포구 희우정로20길 71  126.904288
#
#                 위도
# 0        37.555537
# 1        37.567483
# 2        37.569183
# 3        37.547040
# 4        37.569085
# ...

# %%
df2 = df2.reset_index(drop=True)

# %%
gu_list = ['강남구',
'강동구',
'강북구',
'강서구' ,
'관악구'  ,
'광진구' ,
'구로구'  ,
'금천구'   ,
'노원구'    ,
'도봉구'   ,
'동대문구'  ,
'동작구'   ,
'마포구'   ,
'서대문구'  ,
'서초구'   ,
'성동구'    ,
'성북구' ,
'송파구'   ,
'양천구'    ,
'영등포구',
'용산구'  ,
'은평구'  ,
'종로구'   ,
'중구'   ,
'중랑구']

# %%
# 아직 주소 이름이 잘못 적힌 값들을 delete 하지 못했기에, 구별 구분 자료를 통해 필터링하여, 데이터 삭제.
filtered_df = df2[df2['구별구분'].isin(gu_list)]

print(filtered_df)
# Out:
#          구별구분     민원접수일    민원접수시간                     주소          경도  \
# 0         강서구  20210929  00:05:00      서울 강서구 화곡로66길 130  126.859911
# 1          중구  20210929  00:38:00  중구 다산로48길 33 단우물어린이집앞  127.018013
# 2          중구  20210929  00:38:00        서울특별시 중구 마장로 19  127.012793
# 3         강서구  20210929  00:50:00   서울특별시 강서구 까치산로15길 21  126.847125
# 4          중구  20210929  01:15:00       서울특별시 중구 다산로 293  127.015703
# ...       ...       ...       ...                    ...         ...
# 2146005   서초구  20240313  23:49:00    서울특별시 서초구 잠원로 213-3  127.014999
# 2146006   광진구  20240313  23:54:00    광진구 자양로32길74 교차로모퉁이  127.089311
# 2146007   관악구  20240313  23:55:00  신사동 554-23/ 앞 이면도로 주변  127.024768
# 2146008  동대문구  20240313  23:56:00    서울 동대문구 휘경동 183-127  127.056992
# 2146009   마포구  20240313  23:56:00   서울특별시 마포구 희우정로20길 71  126.904288
#
#                 위도
# 0        37.555537
# 1        37.567483
# 2        37.569183
# 3        37.547040
# 4        37.569085
# ...

# %%
df2['구별구분'].unique() #unique 값을 찍어본 결과, 잘못 산출된 데이터들이 많다.
# Out:
# array(['강서구', '중구', '동작구', '성북구', '강북구', '2번출구', '입구', '출입구', '골목입구',
#        '출구', '1번출구', '도봉구', '8번출구', '(강서구', '강남구', '7번출구', '6번출구', '(중구',
#        '서구', '3번출구', '서울중구', '동대문구', '노원구', '서대문구', '광진구', 'ㄱ아서구', '용산구',
#        '서초구', '4번출구', '공원입구', '관악구', '성동구', '마포구', '5번출구', '송파구', '금천구',
#        '(성북구', ':노원구', '번출구', '계양구', '(송파구', '종로구', '.광진구', '*노원구',
#        '의릉입구', '은평구', '터널입구', '앞입구', '초구', '광징구', '(관악구', '양산구', '영등포구',
#        '구로구', '중랑구', '/송파구', '[송파구', '[파구', '/용산구', '진구', '강동구', '구',
#        '.용산구', '원구', ':강서구', '산구', '(서초구', '(도봉구', '시장입구', '77(구', '양천구',
#        '홍대입구', '(용산구', '.서초구', '[도봉구', '(마포구', '.마포구', '(노원구', '(광진구',
#        '주차입구', '광딘구', '용선구', '(강북구', ':금천구', '~송파구', '빌라입구', ':강북구',
#        '수정구', '라자가구', '9번출구', '옹산구', '.성북구', '[동작구', '동댐누구', ',도봉구',
#        '굉진구', '동대입구', '공.구', '화1.구', '[양천구', '상북구', '주출입구', '(은평구',
#        '현장입구', '(강남구', '동구', '(양천구', '파구', '[용산구', '/은평구', '북구', '(구로구',
# ...

# %%
df2 = filtered_df # 필터링된 값을 df2에 할당

# %%
filtered_df['구별구분'].unique() # 필터링된 값의 unique를 찍어본 결과, 각 구별로 잘 산출됨.
# Out:
# array(['강서구', '중구', '동작구', '성북구', '강북구', '도봉구', '강남구', '동대문구', '노원구',
#        '서대문구', '광진구', '용산구', '서초구', '관악구', '성동구', '마포구', '송파구', '금천구',
#        '종로구', '은평구', '영등포구', '구로구', '중랑구', '강동구', '양천구'], dtype=object)

# %%
df2.reset_index(drop=True) # reset_index를 통해 row 갯수확인
# Out:
#          구별구분     민원접수일    민원접수시간                     주소          경도  \
# 0         강서구  20210929  00:05:00      서울 강서구 화곡로66길 130  126.859911
# 1          중구  20210929  00:38:00  중구 다산로48길 33 단우물어린이집앞  127.018013
# 2          중구  20210929  00:38:00        서울특별시 중구 마장로 19  127.012793
# 3         강서구  20210929  00:50:00   서울특별시 강서구 까치산로15길 21  126.847125
# 4          중구  20210929  01:15:00       서울특별시 중구 다산로 293  127.015703
# ...       ...       ...       ...                    ...         ...
# 2122748   서초구  20240313  23:49:00    서울특별시 서초구 잠원로 213-3  127.014999
# 2122749   광진구  20240313  23:54:00    광진구 자양로32길74 교차로모퉁이  127.089311
# 2122750   관악구  20240313  23:55:00  신사동 554-23/ 앞 이면도로 주변  127.024768
# 2122751  동대문구  20240313  23:56:00    서울 동대문구 휘경동 183-127  127.056992
# 2122752   마포구  20240313  23:56:00   서울특별시 마포구 희우정로20길 71  126.904288
#
#                 위도
# 0        37.555537
# 1        37.567483
# 2        37.569183
# 3        37.547040
# 4        37.569085
# ...

# %%
sorted_df = df2.sort_values(by='구별구분').reset_index(drop=True) # sort_value를 통해 각 행정구역별로 정리.

# %%
fina_data = sorted_df['구별구분'].value_counts() # .성북구 없음

# %%
df2
# Out:
#          구별구분     민원접수일    민원접수시간                     주소          경도  \
# 0         강서구  20210929  00:05:00      서울 강서구 화곡로66길 130  126.859911
# 1          중구  20210929  00:38:00  중구 다산로48길 33 단우물어린이집앞  127.018013
# 2          중구  20210929  00:38:00        서울특별시 중구 마장로 19  127.012793
# 3         강서구  20210929  00:50:00   서울특별시 강서구 까치산로15길 21  126.847125
# 4          중구  20210929  01:15:00       서울특별시 중구 다산로 293  127.015703
# ...       ...       ...       ...                    ...         ...
# 2146005   서초구  20240313  23:49:00    서울특별시 서초구 잠원로 213-3  127.014999
# 2146006   광진구  20240313  23:54:00    광진구 자양로32길74 교차로모퉁이  127.089311
# 2146007   관악구  20240313  23:55:00  신사동 554-23/ 앞 이면도로 주변  127.024768
# 2146008  동대문구  20240313  23:56:00    서울 동대문구 휘경동 183-127  127.056992
# 2146009   마포구  20240313  23:56:00   서울특별시 마포구 희우정로20길 71  126.904288
#
#                 위도
# 0        37.555537
# 1        37.567483
# 2        37.569183
# 3        37.547040
# 4        37.569085
# ...

# %%
df1 = data.copy()

# %%
df2['구별구분'].unique()
# Out:
# array(['강서구', '중구', '동작구', '성북구', '강북구', '도봉구', '강남구', '동대문구', '노원구',
#        '서대문구', '광진구', '용산구', '서초구', '관악구', '성동구', '마포구', '송파구', '금천구',
#        '종로구', '은평구', '영등포구', '구로구', '중랑구', '강동구', '양천구'], dtype=object)

# %%
fina_data
# Out:
# 마포구     221990
# 서초구     194081
# 용산구     163903
# 송파구     141810
# 영등포구    123521
# 중구      115530
# 양천구     109941
# 강동구     100629
# 광진구      96249
# 관악구      93184
# 동대문구     93035
# 종로구      76791
# 강남구      72916
# 은평구      64089
# 서대문구     62506
# 성북구      62491
# 노원구      49783
# 금천구      49686
# 성동구      49465
# 중랑구      43823
# 구로구      42590
# 강북구      37732
# 도봉구      30739
# 강서구      18184
# 동작구       8085
# Name: 구별구분, dtype: int64

# %%
sorted_df
# Out:
#         구별구분     민원접수일    민원접수시간  \
# 0        강남구  20220314  11:52:00
# 1        강남구  20220610  20:56:00
# 2        강남구  20220504  16:35:00
# 3        강남구  20230602  11:02:00
# 4        강남구  20220504  16:31:00
# ...      ...       ...       ...
# 2060257  중랑구  20240218  02:13:00
# 2060258  중랑구  20230315  19:48:00
# 2060259  중랑구  20221211  21:18:00
# 2060260  중랑구  20220130  16:45:00
# 2060261  중랑구  20220917  13:33:00
#
#                                                        주소          경도  \
# 0                                      서울특별시 강남구 삼성로4길 17  127.069724
# 1                                       서울 강남구 논현동 182-29  127.024503
# 2                                    청담동 76-12 / 학동로81길 9  127.050535
# 3        수서동 724 / 버스정류장주변 소나타2053, 2992, 1872, 8286 외 수대  127.102826
# 4                    수서동 713과714사이 수서벤체빌 옆길 어린이보호구역 불법주차   127.102091
# ...                                                   ...         ...
# ...

# %%
fina_data = pd.DataFrame(fina_data)

# %%
fina_data
# Out:
#         구별구분
# 마포구   221990
# 서초구   194081
# 용산구   163903
# 송파구   141810
# 영등포구  123521
# 중구    115530
# 양천구   109941
# 강동구   100629
# 광진구    96249
# 관악구    93184
# 동대문구   93035
# 종로구    76791
# 강남구    72916
# 은평구    64089
# 서대문구   62506
# 성북구    62491
# 노원구    49783
# 금천구    49686
# 성동구    49465
# 중랑구    43823
# 구로구    42590
# 강북구    37732
# 도봉구    30739
# 강서구    18184
# 동작구     8085

# %%
data = {
    '구별구분': ['마포구', '서초구', '용산구', '송파구', '영등포구', '중구', '양천구', '강동구', '광진구', '관악구',
               '동대문구', '종로구', '강남구', '은평구', '서대문구','성북구', '노원구', '금천구', '성동구', '중랑구', '구로구',
               '강북구', '도봉구', '강서구', '동작구'],
    '불법주차수': [221990, 194081, 163903, 141810, 123521, 115530, 109941, 100629, 96249, 93184,
               93035, 76791, 72916, 64089, 62506,62491, 49783, 49686, 49465, 43823, 42590,
               37732, 30739, 18184, 8085]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# %%
df
# Out:
#     구별구분   불법주차수
# 0    마포구  221990
# 1    서초구  194081
# 2    용산구  163903
# 3    송파구  141810
# 4   영등포구  123521
# 5     중구  115530
# 6    양천구  109941
# 7    강동구  100629
# 8    광진구   96249
# 9    관악구   93184
# 10  동대문구   93035
# 11   종로구   76791
# 12   강남구   72916
# 13   은평구   64089
# 14  서대문구   62506
# 15   성북구   62491
# 16   노원구   49783
# 17   금천구   49686
# 18   성동구   49465
# 19   중랑구   43823
# 20   구로구   42590
# 21   강북구   37732
# 22   도봉구   30739
# 23   강서구   18184
# 24   동작구    8085

# %%
df
# Out:
#     구별구분   불법주차수
# 0    마포구  221990
# 1    서초구  194081
# 2    용산구  163903
# 3    송파구  141810
# 4   영등포구  123521
# 5     중구  115530
# 6    양천구  109941
# 7    강동구  100629
# 8    광진구   96249
# 9    관악구   93184
# 10  동대문구   93035
# 11   종로구   76791
# 12   강남구   72916
# 13   은평구   64089
# 14  서대문구   62506
# 15   노원구   49783
# 16   금천구   49686
# 17   성동구   49465
# 18   중랑구   43823
# 19   구로구   42590
# 20   강북구   37732
# 21   도봉구   30739
# 22   강서구   18184
# 23   동작구    8085
# 24   성북구       0

# %%
# row의 index 번호를 통해 통합형식에 맞게 순서대로 재정렬
df4 = df.copy()
df = df4.reindex(index=[12,7,20,22,9,8,19,16,15,21,10,23,0,14,1,17,24,3,6,4,2,13,11,5,18])

# %%
df = df.reset_index(drop=True)

# %%
df = df4.reindex(index=[12,7,21,23,9,8,20,17,16,22,10,24,0,14,1,18,15,3,6,4,2,13,11,5,19])

# %%
df.reset_index(drop=True)
# Out:
#     구별구분   불법주차수
# 0    강남구   72916
# 1    강동구  100629
# 2    강북구   37732
# 3    강서구   18184
# 4    관악구   93184
# 5    광진구   96249
# 6    구로구   42590
# 7    금천구   49686
# 8    노원구   49783
# 9    도봉구   30739
# 10  동대문구   93035
# 11   동작구    8085
# 12   마포구  221990
# 13  서대문구   62506
# 14   서초구  194081
# 15   성동구   49465
# 16   성북구   62491
# 17   송파구  141810
# 18   양천구  109941
# 19  영등포구  123521
# 20   용산구  163903
# 21   은평구   64089
# 22   종로구   76791
# 23    중구  115530
# 24   중랑구   43823

# %%
df.to_csv('불법주정차데이터_전처리.csv',encoding='cp949',index=False)
